# %% [markdown]
# # Preparation of a FEMTIC inversion input files: data and mesh
#
# MMT dummy example in the Mariana Trench to illustrate a MMT survey. Mesh with almost no padding.
#
# The data is fake.

# %%
import sys
sys.path.append('../../src')
import femticPy

# %% [markdown]
# # 1. Preparation of inversion data file

# %%
# the file will be written in the input_data directory
inversion = femticPy.DataGen(survey = 'mmt', outdir = './inversion')

# %%
# Loading the data and the data coordinates
inversion.read_MTdata('./input_data/edi_files/')
inversion.read_MTdata_coordinates('./input_data', 'coords_MT.csv')
# Out:
# Read 15 .edi files
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Z.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_VTF.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Z.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_VTF.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Z.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_VTF.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Z.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_VTF.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Z.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_VTF.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Z.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_VTF.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Z.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_VTF.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Z.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_VTF.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Z.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_VTF.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Z.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_VTF.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Z.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_VTF.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Z.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_VTF.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Z.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_VTF.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Z.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_VTF.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Z.drop(masked, inplace=True)
# /Users/sei029/Documents/projects/strategic_FEMTIC/repo_github/femticpy/src/femticPy.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_VTF.drop(masked, inplace=True)

# %%
## Data to be inverted for
inversion.invert_Z   = True
inversion.invert_VTF = False
inversion.invert_PT  = False

# %%
# load the 3 files needed to create the mesh
inversion.topography = './input_data/topography.dat'
inversion.bathymetry = './input_data/bathymetry.dat'
inversion.coast_line = './input_data/coast_line.dat'

# %%
# we center the data to a anchor point (center of the data set) which will also be the center of the future mesh
inversion.center_data()
inversion.anchor
# Out:
# [1240.0, 620.0]

# %%
# we define the analysis domain, the extent of the total mesh including padding
inversion.analysis_domain = [[-150.0, 150.0],
                                [-150.0, 150.0],
                                [-150.0, 150.0]]
inversion.plot_data_loc(plot_ids = False, zoom_core=False)
inversion.plot_coast_line()
inversion.plot_topo_bathy()

# %%
inversion.mt_coords
# Out:
#     id  east  north        z
# 0   01 -20.0   60.0  5.06143
# 1   02 -20.0   30.0  7.37934
# 2   03 -20.0    0.0  9.26227
# 3   04 -20.0  -30.0  6.60975
# 4   05 -20.0  -60.0  4.94718
# 5   06   0.0   60.0  5.71539
# 6   07   0.0   30.0  7.41213
# 7   08   0.0    0.0  9.49203
# 8   09   0.0  -30.0  6.37154
# 9   10   0.0  -60.0  4.98219
# 10  11  20.0   60.0  3.26538
# 11  12  20.0   30.0  8.73988
# 12  13  20.0    0.0  9.02320
# 13  14  20.0  -30.0  6.46191
# 14  15  20.0  -60.0  5.03869

# %%
inversion.data_Z
# Out:
# [        FREQ      ZXXR      ZXXI       ZXX.VAR       ZXYR       ZXYI  \
#  0  10.000000 -0.004106 -0.004131  3.392709e-13  49.955220  49.667360
#  1   3.162278  0.064002  0.010007  4.196386e-11  28.201800  28.574550
#  2   1.000000 -0.016317  0.222148  4.961613e-10  14.976720  16.148060
#  3   0.316228 -0.329728  0.207431  1.517485e-09   8.215382   8.677465
#  4   0.100000 -0.395555 -0.027992  1.572475e-09   4.606873   4.772003
#  5   0.031623 -0.269751 -0.119247  8.698517e-10   2.576848   2.643806
#  6   0.010000 -0.158556 -0.106640  3.651229e-10   1.443410   1.469043
#  7   0.003162 -0.090260 -0.073027  1.347982e-10   0.812470   0.818905
#  8   0.001000 -0.050935 -0.045397  4.655299e-11   0.457180   0.459233
#
#          ZXY.VAR       ZYXR       ZYXI       ZYX.VAR      ZYYR      ZYYI  \
#  0  4.962370e-05 -49.984520 -49.615990  4.960199e-05  0.001919  0.001865
#  1  1.611846e-05 -28.428140 -28.852100  1.640602e-05 -0.026095 -0.007129
#  2  4.850618e-06 -14.498550 -16.929990  4.968326e-06  0.021323 -0.079223
#  3  1.427909e-06  -7.032982  -8.825746  1.273566e-06  0.112234 -0.038851
#  4  4.399529e-07  -3.802340  -4.412668  3.392942e-07  0.098071  0.024687
#  5  1.362986e-07  -2.149359  -2.327813  1.003846e-07  0.058984  0.034050
#  6  4.241518e-08  -1.208581  -1.266158  3.063823e-08  0.033340  0.025483
#  7  1.330714e-08  -0.680388  -0.697368  9.492511e-09  0.018767  0.016258
#  8  4.199090e-09  -0.382778  -0.388263  2.972671e-09  0.010556  0.009767
#
#          ZYY.VAR
#  0  7.158388e-14
#  1  7.317673e-12
#  2  6.730956e-11
#  3  1.410586e-10
#  4  1.022737e-10
#  5  4.638501e-11
#  6  1.760956e-11
#  7  6.165464e-12
#  8  2.068271e-12  ,
#          FREQ      ZXXR      ZXXI       ZXX.VAR       ZXYR       ZXYI  \
#  0  10.000000 -0.005519 -0.004597  5.159912e-13  49.610050  49.973380
#  1   3.162278  0.074425  0.019850  5.933033e-11  28.045270  26.737790
#  2   1.000000 -0.048061  0.218954  5.025076e-10  17.372890  15.067670
#  3   0.316228 -0.314842  0.163763  1.259436e-09  10.418280   9.071069
#  4   0.100000 -0.348232 -0.037716  1.226883e-09   6.043580   5.462676
#  5   0.031623 -0.233799 -0.108140  6.635644e-10   3.439805   3.223426
#  6   0.010000 -0.136994 -0.093767  2.755965e-10   1.941451   1.867085
#  7   0.003162 -0.077944 -0.063589  1.011890e-10   1.095916   1.067772
#  8   0.001000 -0.043982 -0.039367  3.484145e-11   0.617263   0.607952
#
#          ZXY.VAR       ZYXR       ZYXI       ZYX.VAR      ZYYR      ZYYI  \
#  0  4.958496e-05 -49.653470 -49.782460  4.943760e-05  0.000458  0.003894
#  1  1.501446e-05 -28.693190 -27.705620  1.590901e-05 -0.018218 -0.013515
#  2  5.288519e-06 -15.819690 -16.842610  5.339361e-06  0.014043 -0.065623
#  3  1.908248e-06  -7.715768  -9.288747  1.458139e-06  0.104877 -0.050101
#  4  6.636568e-07  -4.093981  -4.710892  3.895318e-07  0.106518  0.017134
#  5  2.222273e-07  -2.302008  -2.487781  1.148830e-07  0.068636  0.034258
#  6  7.255238e-08  -1.294066  -1.353594  3.506823e-08  0.039923  0.028166
#  7  2.341169e-08  -0.728772  -0.746001  1.087627e-08  0.022705  0.018779
#  8  7.506201e-09  -0.410070  -0.415581  3.408651e-09  0.012816  0.011546
#
#          ZYY.VAR
#  0  1.537442e-13
#  1  5.145457e-12
#  2  4.503544e-11
#  3  1.350920e-10
#  4  1.163974e-10
#  5  5.884543e-11
#  6  2.387164e-11
#  7  8.681646e-12
#  8  2.975637e-12  ,
#          FREQ      ZXXR      ZXXI       ZXX.VAR       ZXYR       ZXYI  \
#  0  10.000000 -0.001703 -0.000748  3.459754e-14  50.336490  49.490920
#  1   3.162278  0.021104  0.003794  4.597736e-12  27.995280  29.802090
#  2   1.000000 -0.019090  0.057054  3.619547e-11  13.547110  16.702040
#  3   0.316228 -0.074725  0.026310  6.275967e-11   6.793747   8.534692
#  4   0.100000 -0.070947 -0.012179  5.181865e-11   3.589141   4.341734
#  5   0.031623 -0.047089 -0.022836  2.738866e-11   1.964158   2.244454
#  6   0.010000 -0.027781 -0.019188  1.139991e-11   1.093388   1.189999
#  7   0.003162 -0.015871 -0.012957  4.197856e-12   0.614387   0.644388
#  8   0.001000 -0.008969 -0.008023  1.448251e-12   0.345547   0.355165
#
#          ZXY.VAR       ZYXR       ZYXI       ZYX.VAR      ZYYR      ZYYI  \
#  0  4.983113e-05 -50.315310 -49.473700  4.979277e-05  0.001540  0.001334
#  1  1.671900e-05 -28.230650 -29.912440  1.691723e-05 -0.016525 -0.005342
#  2  4.624821e-06 -13.197380 -17.195480  4.698555e-06  0.011776 -0.051352
#  3  1.189960e-06  -6.158748  -8.478991  1.098235e-06  0.072570 -0.031594
#  4  3.173259e-07  -3.297162  -4.095548  2.764479e-07  0.073009  0.010417
#  5  8.895491e-08  -1.854289  -2.102205  7.857654e-08  0.048932  0.022856
#  6  2.611596e-08  -1.040410  -1.121668  2.340592e-08  0.029063  0.019660
#  7  7.927073e-09  -0.585180  -0.610238  7.148255e-09  0.016662  0.013431
#  8  2.455447e-09  -0.329118  -0.337211  2.220304e-09  0.009432  0.008369
#
#          ZYY.VAR
#  0  4.151197e-14
#  1  3.016264e-12
#  2  2.775679e-11
#  3  6.264530e-11
#  4  5.438833e-11
#  5  2.916715e-11
#  6  1.231137e-11
#  7  4.580220e-12
#  8  1.589945e-12  ,
#          FREQ      ZXXR      ZXXI       ZXX.VAR       ZXYR       ZXYI  \
#  0  10.000000  0.001949 -0.015254  2.364773e-12  49.883000  49.824840
#  1   3.162278  0.030696  0.090868  9.199198e-11  27.876180  27.748440
#  2   1.000000 -0.171844  0.001655  2.953304e-10  16.235860  15.362190
#  3   0.316228  0.013739 -0.204794  4.212941e-10   9.473989   8.874379
#  4   0.100000  0.191484 -0.063634  4.071548e-10   5.415299   5.152465
#  5   0.031623  0.151464  0.039935  2.453619e-10   3.066483   2.965658
#  6   0.010000  0.090750  0.052302  1.097099e-10   1.728070   1.692795
#  7   0.003162  0.051737  0.039118  4.206965e-11   0.975000   0.960055
#  8   0.001000  0.029199  0.025149  1.485056e-11   0.549082   0.544043
#
#          ZXY.VAR       ZYXR       ZYXI       ZYX.VAR      ZYYR      ZYYI  \
#  0  4.970828e-05 -49.874620 -49.818880  4.969399e-05  0.000926  0.013600
#  1  1.547057e-05 -28.037730 -27.774710  1.557549e-05 -0.071203 -0.074232
#  2  4.996002e-06 -16.114490 -15.862720  5.113024e-06  0.152462 -0.156670
#  3  1.685111e-06  -8.765528  -9.103628  1.597105e-06  0.207186  0.020201
#  4  5.587336e-07  -4.836102  -4.976435  4.815279e-07  0.124212  0.062210
#  5  1.819845e-07  -2.732898  -2.761179  1.509284e-07  0.072395  0.049849
#  6  5.851781e-08  -1.537861  -1.546677  4.757225e-08  0.041860  0.033642
#  7  1.872331e-08  -0.866424  -0.867043  1.502455e-08  0.023905  0.020976
#  8  5.974739e-09  -0.487591  -0.487810  4.757039e-09  0.013523  0.012543
#
#          ZYY.VAR
#  0  1.858246e-12
#  1  1.058032e-10
#  2  4.779028e-10
#  3  4.333433e-10
#  4  1.929868e-10
#  5  7.725918e-11
#  6  2.884089e-11
#  7  1.011445e-11
#  8  3.402009e-12  ,
#          FREQ      ZXXR      ZXXI       ZXX.VAR       ZXYR       ZXYI  \
#  0  10.000000  0.000597  0.003983  1.621725e-13  49.764140  49.947780
#  1   3.162278 -0.003317 -0.025400  6.561725e-12  27.891890  27.074740
#  2   1.000000  0.047903  0.025100  2.924717e-11  17.017090  15.181640
#  3   0.316228 -0.043908  0.084767  9.113408e-11  10.024260   9.065185
#  4   0.100000 -0.102708  0.013799  1.073930e-10   5.733467   5.353534
#  5   0.031623 -0.074810 -0.026271  6.286773e-11   3.246073   3.107958
#  6   0.010000 -0.044121 -0.027659  2.711670e-11   1.829070   1.781966
#  7   0.003162 -0.025066 -0.019689  1.015975e-11   1.031959   1.013075
#  8   0.001000 -0.014130 -0.012418  3.538744e-12   0.581148   0.574855
#
#          ZXY.VAR       ZYXR       ZYXI       ZYX.VAR      ZYYR      ZYYI  \
#  0  4.971250e-05 -49.764280 -49.902140  4.966707e-05 -0.003373 -0.006185
#  1  1.510999e-05 -28.151200 -27.295950  1.537559e-05  0.040102  0.035493
#  2  5.200637e-06 -16.636460 -15.941000  5.308872e-06 -0.073116  0.079794
#  3  1.826634e-06  -8.874470  -9.369468  1.665431e-06 -0.104967 -0.003923
#  4  6.153296e-07  -4.787541  -5.067580  4.860092e-07 -0.068874 -0.029240
#  5  2.019640e-07  -2.689662  -2.771422  1.491506e-07 -0.041615 -0.026412
#  6  6.520900e-08  -1.511989  -1.538424  4.652862e-08 -0.024194 -0.018705
#  7  2.091260e-08  -0.851735  -0.857996  1.461610e-08 -0.013822 -0.011899
#  8  6.681911e-09  -0.479317  -0.481323  4.614166e-09 -0.007818 -0.007181
#
#          ZYY.VAR
#  0  4.962464e-13
#  1  2.867895e-11
#  2  1.171297e-10
#  3  1.103334e-10
#  4  5.598577e-11
#  5  2.429463e-11
#  6  9.352224e-12
#  7  3.326547e-12
#  8  1.126900e-12  ,
#          FREQ      ZXXR      ZXXI       ZXX.VAR       ZXYR       ZXYI  \
#  0  10.000000  0.002465  0.001717  9.020779e-14  50.330250  49.503680
#  1   3.162278 -0.031721 -0.007940  1.069274e-11  27.985360  29.751370
#  2   1.000000  0.030788 -0.086173  8.373691e-11  13.614920  16.662440
#  3   0.316228  0.114120 -0.039169  1.455765e-10   6.862931   8.543922
#  4   0.100000  0.107779  0.018951  1.197545e-10   3.635429   4.362333
#  5   0.031623  0.071388  0.034863  6.311675e-11   1.992277   2.262710
#  6   0.010000  0.042089  0.029148  2.621090e-11   1.109635   1.202790
#  7   0.003162  0.024042  0.019657  9.643861e-12   0.623628   0.652446
#  8   0.001000  0.013590  0.012158  3.324948e-12   0.350765   0.359996
#
#          ZXY.VAR       ZYXR       ZYXI       ZYX.VAR      ZYYR      ZYYI  \
#  0  4.983748e-05 -50.312390 -49.491720  4.980767e-05 -0.002207 -0.002367
#  1  1.668325e-05 -28.186680 -29.832410  1.684462e-05  0.026798  0.009275
#  2  4.630030e-06 -13.318710 -17.091720  4.695150e-06 -0.021143  0.082748
#  3  1.200984e-06  -6.320641  -8.462627  1.115666e-06 -0.116446  0.048146
#  4  3.224629e-07  -3.435479  -4.131348  2.887056e-07 -0.114886 -0.017595
#  5  9.089026e-08  -1.944579  -2.150311  8.405223e-08 -0.076681 -0.036269
#  6  2.677993e-08  -1.093352  -1.159750  2.540439e-08 -0.045482 -0.030926
#  7  8.145987e-09  -0.615366  -0.635398  7.824062e-09 -0.026072 -0.021071
#  8  2.526332e-09  -0.346167  -0.352628  2.441781e-09 -0.014758 -0.013113
#
#          ZYY.VAR
#  0  1.047672e-13
#  1  8.041571e-12
#  2  7.294182e-11
#  3  1.587778e-10
#  4  1.350832e-10
#  5  7.195379e-11
#  6  3.024994e-11
#  7  1.123740e-11
#  8  3.897546e-12  ,
#          FREQ      ZXXR      ZXXI       ZXX.VAR       ZXYR       ZXYI  \
#  0  10.000000  0.007018  0.009394  1.375086e-12  49.627330  49.950950
#  1   3.162278 -0.109722 -0.039705  1.361531e-10  28.036730  26.835330
#  2   1.000000  0.083583 -0.325108  1.126810e-09  17.269540  15.084930
#  3   0.316228  0.470556 -0.235314  2.767951e-09  10.347270   9.047976
#  4   0.100000  0.514169  0.058951  2.678448e-09   5.999991   5.436831
#  5   0.031623  0.344608  0.160526  1.445235e-09   3.415015   3.204278
#  6   0.010000  0.201887  0.138519  5.994562e-10   1.927546   1.854921
#  7   0.003162  0.114871  0.093819  2.199739e-10   1.088089   1.060510
#  8   0.001000  0.064825  0.058044  7.571316e-11   0.612861   0.603727
#
#          ZXY.VAR       ZYXR       ZYXI       ZYX.VAR      ZYYR      ZYYI  \
#  0  4.957969e-05 -49.660080 -49.783250  4.944496e-05 -0.000211 -0.006613
#  1  1.506193e-05 -28.652190 -27.696340  1.588036e-05  0.031178  0.024598
#  2  5.257921e-06 -15.855280 -16.752330  5.320303e-06 -0.030298  0.109255
#  3  1.889318e-06  -7.833719  -9.250899  1.469463e-06 -0.171642  0.074705
#  4  6.555903e-07  -4.202362  -4.733012  4.006124e-07 -0.169132 -0.029684
#  5  2.192973e-07  -2.371461  -2.523979  1.199430e-07 -0.108638 -0.054999
#  6  7.156164e-08  -1.334296  -1.382584  3.691883e-08 -0.063154 -0.044795
#  7  2.308619e-08  -0.751597  -0.765114  1.150297e-08 -0.035922 -0.029786
#  8  7.400837e-09  -0.422938  -0.427261  3.614286e-09 -0.020278 -0.018293
#
#          ZYY.VAR
#  0  4.377591e-13
#  1  1.577155e-11
#  2  1.285460e-10
#  3  3.504171e-10
#  4  2.948671e-10
#  5  1.482718e-10
#  6  5.995083e-11
#  7  2.177617e-11
#  8  7.458300e-12  ,
#          FREQ      ZXXR      ZXXI       ZXX.VAR       ZXYR       ZXYI  \
#  0  10.000000  0.001038  0.014503  2.114102e-12  49.915180  49.717920
#  1   3.162278 -0.102019 -0.058373  1.381528e-10  28.186470  28.315280
#  2   1.000000  0.078786 -0.348521  1.276741e-09  15.316510  16.082350
#  3   0.316228  0.531903 -0.300139  3.730043e-09   8.383903   8.803831
#  4   0.100000  0.618225  0.054628  3.851871e-09   4.671312   4.843489
#  5   0.031623  0.419187  0.189512  2.116322e-09   2.612614   2.680170
#  6   0.010000  0.245870  0.166932  8.831851e-10   1.464314   1.489279
#  7   0.003162  0.139867  0.113718  3.249444e-10   0.824499   0.830480
#  8   0.001000  0.078915  0.070512  1.119950e-10   0.464002   0.465872
#
#          ZXY.VAR       ZYXR       ZYXI       ZYX.VAR      ZYYR      ZYYI  \
#  0  4.963396e-05 -49.922020 -49.707230  4.963016e-05 -0.001068 -0.012822
#  1  1.596232e-05 -28.230820 -28.371000  1.601893e-05  0.079947  0.065012
#  2  4.932376e-06 -15.195380 -16.253100  4.950627e-06 -0.130081  0.212768
#  3  1.477973e-06  -8.128378  -8.684626  1.414933e-06 -0.302407  0.054589
#  4  4.528055e-07  -4.716208  -4.667285  4.402616e-07 -0.237883 -0.075414
#  5  1.400906e-07  -2.728691  -2.650888  1.447296e-07 -0.142119 -0.086364
#  6  4.362167e-08  -1.544211  -1.514334  4.677795e-08 -0.080544 -0.062695
#  7  1.369496e-08  -0.870946  -0.858819  1.496117e-08 -0.045429 -0.039650
#  8  4.323343e-09  -0.490250  -0.486376  4.769065e-09 -0.025571 -0.023743
#
#          ZYY.VAR
#  0  1.655518e-12
#  1  1.061802e-10
#  2  6.219113e-10
#  3  9.442983e-10
#  4  6.227554e-10
#  5  2.765651e-10
#  6  1.041802e-10
#  7  3.635923e-11
#  8  1.217615e-11  ,
#          FREQ      ZXXR      ZXXI       ZXX.VAR       ZXYR       ZXYI  \
#  0  10.000000  0.003754  0.020206  4.223737e-12  49.855630  49.835400
#  1   3.162278 -0.145531 -0.082621  2.800541e-10  27.910980  27.681550
#  2   1.000000  0.136395 -0.460915  2.310465e-09  16.289360  15.350560
#  3   0.316228  0.683100 -0.342867  5.841832e-09   9.540885   8.868281
#  4   0.100000  0.758106  0.080785  5.812513e-09   5.474795   5.167018
#  5   0.031623  0.512457  0.235127  3.178972e-09   3.106899   2.985830
#  6   0.010000  0.301083  0.205048  1.326954e-09   1.752363   1.709457
#  7   0.003162  0.171469  0.139469  4.885320e-10   0.988999   0.971369
#  8   0.001000  0.096796  0.086467  1.684598e-10   0.557022   0.551088
#
#          ZXY.VAR       ZYXR       ZYXI       ZYX.VAR      ZYYR      ZYYI  \
#  0  4.969150e-05 -49.843710 -49.801590  4.964593e-05 -0.002076 -0.016072
#  1  1.545291e-05 -28.193890 -27.872070  1.571748e-05  0.099947  0.071067
#  2  5.009828e-06 -15.840620 -16.073160  5.092717e-06 -0.123915  0.300082
#  3  1.696749e-06  -8.548631  -8.899700  1.522838e-06 -0.442275  0.151972
#  4  5.667145e-07  -4.896469  -4.841128  4.741193e-07 -0.411610 -0.081964
#  5  1.856801e-07  -2.816379  -2.746539  1.547547e-07 -0.265488 -0.135833
#  6  5.993021e-08  -1.591568  -1.565357  4.983432e-08 -0.155129 -0.109963
#  7  1.921676e-08  -0.897438  -0.886491  1.591262e-08 -0.088433 -0.073176
#  8  6.139711e-09  -0.505139  -0.501647  5.068147e-09 -0.049962 -0.044993
#
#          ZYY.VAR
#  0  2.626292e-12
#  1  1.503988e-10
#  2  1.054043e-09
#  3  2.187023e-09
#  4  1.761404e-09
#  5  8.893462e-10
#  6  3.615674e-10
#  7  1.317510e-10
#  8  4.520544e-11  ,
#          FREQ      ZXXR      ZXXI       ZXX.VAR       ZXYR       ZXYI  \
#  0  10.000000  0.003651  0.004905  3.738765e-13  49.996140  49.648190
#  1   3.162278 -0.055879 -0.021100  3.567648e-11  28.196730  28.699170
#  2   1.000000  0.056165 -0.160801  2.901147e-10  14.863900  16.326160
#  3   0.316228  0.219881 -0.079353  5.464468e-10   7.858238   8.802343
#  4   0.100000  0.211093  0.035612  4.582864e-10   4.272605   4.694215
#  5   0.031623  0.140032  0.067978  2.422987e-10   2.372712   2.528230
#  6   0.010000  0.082510  0.057062  1.006394e-10   1.328110   1.381385
#  7   0.003162  0.047113  0.038505  3.702309e-11   0.747667   0.762827
#  8   0.001000  0.026627  0.023820  1.276419e-11   0.420756   0.425530
#
#          ZXY.VAR       ZYXR       ZYXI       ZYX.VAR      ZYYR      ZYYI  \
#  0  4.964556e-05 -49.961710 -49.694710  4.965737e-05 -0.004217 -0.007057
#  1  1.618698e-05 -28.097230 -28.428950  1.597660e-05  0.079213  0.029204
#  2  4.874790e-06 -15.179000 -15.972850  4.855340e-06 -0.074308  0.238991
#  3  1.392332e-06  -8.477656  -8.465020  1.435272e-06 -0.332161  0.122160
#  4  4.029080e-07  -5.117668  -4.697703  4.825894e-07 -0.315277 -0.054321
#  5  1.202171e-07  -3.002053  -2.771143  1.669155e-07 -0.209292 -0.100861
#  6  3.672101e-08  -1.705697  -1.622146  5.540762e-08 -0.124164 -0.084945
#  7  1.140912e-08  -0.963119  -0.932979  1.798048e-08 -0.071204 -0.057685
#  8  3.581111e-09  -0.542322  -0.532613  5.777899e-09 -0.040313 -0.035857
#
#          ZYY.VAR
#  0  6.758553e-13
#  1  7.127648e-11
#  2  6.263847e-10
#  3  1.252537e-09
#  4  1.023504e-09
#  5  5.397630e-10
#  6  2.263239e-10
#  7  8.397600e-11
#  8  2.910861e-11  ,
#          FREQ      ZXXR      ZXXI       ZXX.VAR       ZXYR       ZXYI  \
#  0  10.000000 -0.003294 -0.005980  4.661213e-13  50.088560  49.615760
#  1   3.162278  0.057708  0.026260  4.019829e-11  28.133290  28.978040
#  2   1.000000 -0.064373  0.163646  3.092386e-10  14.534000  16.410660
#  3   0.316228 -0.224563  0.076203  5.623561e-10   7.595003   8.734409
#  4   0.100000 -0.212533 -0.037703  4.659191e-10   4.104052   4.605819
#  5   0.031623 -0.140593 -0.068899  2.451364e-10   2.272619   2.457773
#  6   0.010000 -0.082789 -0.057491  1.015923e-10   1.270785   1.334234
#  7   0.003162 -0.047262 -0.038705  3.731797e-11   0.715152   0.733780
#  8   0.001000 -0.026706 -0.023924  1.285583e-11   0.402415   0.408317
#
#          ZXY.VAR       ZYXR       ZYXI       ZYX.VAR      ZYYR      ZYYI  \
#  0  4.970587e-05 -50.048870 -49.654020  4.970410e-05  0.003541  0.008196
#  1  1.631208e-05 -28.091950 -28.737170  1.614983e-05 -0.077939 -0.035466
#  2  4.805470e-06 -14.777950 -16.188090  4.804419e-06  0.081807 -0.232736
#  3  1.339740e-06  -8.038681  -8.442285  1.358926e-06  0.325120 -0.113425
#  4  3.805681e-07  -4.793177  -4.573659  4.389290e-07  0.304929  0.054920
#  5  1.120545e-07  -2.802858  -2.647347  1.486446e-07  0.201791  0.098193
#  6  3.395075e-08  -1.591299  -1.533100  4.882628e-08  0.119632  0.082182
#  7  1.049876e-08  -0.898323  -0.876589  1.575393e-08  0.068587  0.055679
#  8  3.286606e-09  -0.505804  -0.498787  5.046270e-09  0.038828  0.034573
#
#          ZYY.VAR
#  0  7.970903e-13
#  1  7.332344e-11
#  2  6.085834e-10
#  3  1.185681e-09
#  4  9.599803e-10
#  5  5.036142e-10
#  6  2.106572e-10
#  7  7.804255e-11
#  8  2.702931e-11  ,
#          FREQ      ZXXR      ZXXI       ZXX.VAR       ZXYR       ZXYI  \
#  0  10.000000 -0.000913 -0.025061  6.289076e-12  49.812760  49.855990
#  1   3.162278  0.160729  0.108731  3.765632e-10  27.923020  27.517140
#  2   1.000000 -0.177390  0.507478  2.890012e-09  16.490770  15.273680
#  3   0.316228 -0.755372  0.352935  6.951495e-09   9.727935   8.896839
#  4   0.100000 -0.816250 -0.098403  6.759469e-09   5.601717   5.225612
#  5   0.031623 -0.548388 -0.255969  3.662497e-09   3.182871   3.036683
#  6   0.010000 -0.321724 -0.220665  1.521996e-09   1.795927   1.744445
#  7   0.003162 -0.183154 -0.149499  5.589514e-10   1.013713   0.993178
#  8   0.001000 -0.103376 -0.092528  1.924814e-10   0.570963   0.564086
#
#          ZXY.VAR       ZYXR       ZYXI       ZYX.VAR      ZYYR      ZYYI  \
#  0  4.966931e-05 -49.795650 -49.802670  4.959913e-05 -0.001290  0.018385
#  1  1.536888e-05 -28.290110 -27.798510  1.573087e-05 -0.095262 -0.083592
#  2  5.052306e-06 -15.889310 -16.189890  5.145826e-06  0.135505 -0.296241
#  3  1.737865e-06  -8.452207  -8.970466  1.519091e-06  0.444339 -0.144755
#  4  5.868625e-07  -4.796221  -4.831323  4.634542e-07  0.408083  0.085315
#  5  1.935211e-07  -2.752312  -2.716021  1.495199e-07  0.261750  0.135791
#  6  6.268441e-08  -1.554631  -1.539532  4.787034e-08  0.152668  0.108953
#  7  2.014016e-08  -0.876524  -0.869201  1.523806e-08  0.086973  0.072230
#  8  6.441918e-09  -0.493356  -0.491018  4.844993e-09  0.049126  0.044330
#
#          ZYY.VAR
#  0  3.396587e-12
#  1  1.606238e-10
#  2  1.061204e-09
#  3  2.183909e-09
#  4  1.738103e-09
#  5  8.695221e-10
#  6  3.517827e-10
#  7  1.278154e-10
#  8  4.378520e-11  ,
#          FREQ      ZXXR      ZXXI       ZXX.VAR       ZXYR       ZXYI  \
#  0  10.000000 -0.002523 -0.011496  1.385296e-12  49.899240  49.732480
#  1   3.162278  0.089887  0.043764  9.994961e-11  28.190890  28.235260
#  2   1.000000 -0.055359  0.305471  9.637698e-10  15.414790  16.071110
#  3   0.316228 -0.467321  0.282125  2.979837e-09   8.429390   8.840658
#  4   0.100000 -0.560371 -0.041743  3.157583e-09   4.688173   4.863688
#  5   0.031623 -0.382084 -0.169979  1.748810e-09   2.621718   2.690111
#  6   0.010000 -0.224286 -0.151397  7.322514e-10   1.469596   1.494633
#  7   0.003162 -0.127591 -0.103461  2.698366e-10   0.827533   0.833479
#  8   0.001000 -0.071985 -0.064240  9.308603e-11   0.465722   0.467571
#
#          ZXY.VAR       ZYXR       ZYXI       ZYX.VAR      ZYYR      ZYYI  \
#  0  4.963254e-05 -49.899730 -49.732750  4.963330e-05  0.002309  0.011948
#  1  1.591956e-05 -28.188280 -28.231250  1.591583e-05 -0.081009 -0.060581
#  2  4.958963e-06 -15.392450 -16.085290  4.956641e-06  0.126845 -0.209194
#  3  1.492118e-06  -8.409181  -8.665708  1.458088e-06  0.293676 -0.051591
#  4  4.563442e-07  -4.936935  -4.738446  4.682619e-07  0.229598  0.073588
#  5  1.411011e-07  -2.865925  -2.731394  1.567404e-07  0.136851  0.083562
#  6  4.393641e-08  -1.623311  -1.574249  5.113399e-08  0.077515  0.060491
#  7  1.379499e-08  -0.915796  -0.897300  1.643829e-08  0.043708  0.038202
#  8  4.355195e-09  -0.515536  -0.509617  5.254871e-09  0.024601  0.022859
#
#          ZYY.VAR
#  0  1.480762e-12
#  1  1.023258e-10
#  2  5.985176e-10
#  3  8.890742e-10
#  4  5.813041e-10
#  5  2.571076e-10
#  6  9.667755e-11
#  7  3.369818e-11
#  8  1.127737e-11  ,
#          FREQ      ZXXR      ZXXI       ZXX.VAR       ZXYR       ZXYI  \
#  0  10.000000  0.002976  0.001637  1.153310e-13  49.954680  49.661990
#  1   3.162278 -0.041796 -0.001371  1.748810e-11  28.215160  28.600410
#  2   1.000000  0.003365 -0.148181  2.196880e-10  14.934430  16.168290
#  3   0.316228  0.219184 -0.143972  6.876976e-10   8.186628   8.663475
#  4   0.100000  0.267278  0.016871  7.172230e-10   4.593614   4.761586
#  5   0.031623  0.182731  0.080074  3.980263e-10   2.569160   2.637480
#  6   0.010000  0.107457  0.072023  1.673442e-10   1.438915   1.465144
#  7   0.003162  0.061182  0.049420  6.185570e-11   0.809892   0.816560
#  8   0.001000  0.034530  0.030743  2.137492e-11   0.455720   0.457854
#
#          ZXY.VAR       ZYXR       ZYXI       ZYX.VAR      ZYYR      ZYYI  \
#  0  4.961784e-05 -49.982640 -49.608050  4.959222e-05 -0.001171 -0.000752
#  1  1.614079e-05 -28.464230 -28.888920  1.644782e-05  0.014995  0.002210
#  2  4.844510e-06 -14.435360 -17.016920  4.979552e-06 -0.008927  0.048233
#  3  1.420767e-06  -6.907020  -8.854852  1.261153e-06 -0.069052  0.027083
#  4  4.377399e-07  -3.688804  -4.387502  3.285744e-07 -0.062075 -0.014709
#  5  1.355689e-07  -2.075811  -2.289359  9.550156e-08 -0.037370 -0.021344
#  6  4.217123e-08  -1.165733  -1.235387  2.885114e-08 -0.021081 -0.016069
#  7  1.322696e-08  -0.656025  -0.677034  8.887442e-09 -0.011859 -0.010267
#  8  4.173108e-09  -0.369032  -0.375814  2.774213e-09 -0.006668 -0.006170
#
#          ZYY.VAR
#  0  1.936277e-14
#  1  2.297370e-12
#  2  2.406157e-11
#  3  5.501621e-11
#  4  4.069706e-11
#  5  1.852127e-11
#  6  7.026204e-12
#  7  2.460361e-12
#  8  8.253323e-13  ,
#          FREQ      ZXXR      ZXXI       ZXX.VAR       ZXYR       ZXYI  \
#  0  10.000000 -0.000052 -0.007141  5.099741e-13  49.770760  49.931520
#  1   3.162278  0.006073  0.042676  1.858166e-11  27.896740  27.145410
#  2   1.000000 -0.076987 -0.032056  6.954570e-11  16.937370  15.200720
#  3   0.316228  0.055491 -0.123452  1.831957e-10   9.969424   9.045552
#  4   0.100000  0.143364 -0.022504  2.105971e-10   5.702216   5.333345
#  5   0.031623  0.105218  0.035925  1.236145e-10   3.228550   3.093864
#  6   0.010000  0.062139  0.038589  5.350362e-11   1.819237   1.773204
#  7   0.003162  0.035319  0.027623  2.010436e-11   1.026417   1.007889
#  8   0.001000  0.019916  0.017454  7.013029e-12   0.578029   0.571849
#
#          ZXY.VAR       ZYXR       ZYXI       ZYX.VAR      ZYYR      ZYYI  \
#  0  4.970285e-05 -49.766050 -49.897380  4.966408e-05  0.003390  0.010244
#  1  1.515101e-05 -28.144270 -27.315740  1.538249e-05 -0.056368 -0.056397
#  2  5.179365e-06 -16.618650 -15.920060  5.296278e-06  0.110993 -0.115149
#  3  1.812114e-06  -8.896143  -9.347269  1.665128e-06  0.154075  0.007607
#  4  6.095984e-07  -4.815246  -5.068413  4.887540e-07  0.100485  0.043376
#  5  1.999553e-07  -2.707782  -2.779444  1.505739e-07  0.060564  0.038722
#  6  6.453878e-08  -1.522467  -1.545555  4.706647e-08  0.035219  0.027318
#  7  2.069373e-08  -0.857669  -0.862840  1.480090e-08  0.020117  0.017345
#  8  6.611288e-09  -0.482660  -0.484319  4.675259e-09  0.011378  0.010458
#
#          ZYY.VAR
#  0  1.164324e-12
#  1  6.357951e-11
#  2  2.557875e-10
#  3  2.379691e-10
#  4  1.197870e-10
#  5  5.167395e-11
#  6  1.986644e-11
#  7  7.055630e-12
#  8  2.388390e-12  ]

# %%
# Set up error floors
# x% of (srqt(Zxy^2 + Zyx^2))
inversion.error_floor_Z = [0.2, 0.05, 0.05, 0.2]  # [Zxx, Zxy, Zyx, Zyy]

# %%
subsampling = 2
inversion.freqs[::subsampling]
# Out:
# array([1.e+01, 1.e+00, 1.e-01, 1.e-02, 1.e-03])

# %%
inversion.write_observe(write = True, freq_bandwidth = [0.0001,150], subsampling = subsampling)
# Out:
# Inversion data summary:
#
#   Inverting for 5 frequencies
#
#
#   Impedance Z:
#
#   15 MT sites
#
#   600 Impedance tensor data points (full Z tensor, Real and Imag data)
#
#   Data points per frequencies:
#
#     T = 1.000E+03s  nData =  15
#
#     T = 1.000E+02s  nData =  15
#
#     T = 1.000E+01s  nData =  15
#
#     T = 1.000E+00s  nData =  15
#
#     T = 1.000E-01s  nData =  15

# %% [markdown]
# # 2. Preparation of inversion control file

# %%
# Define inversion parameters:

#TRADE_OFF_PARAM
TRADE_OFF_PARAM = [3]

# Max number of iterations
ITERATION = 10

# NUM_THREADS
NUM_THREADS = 4

# CONVERGE
CONVERGE = 0.2

# %%
inversion.write_inversion_control(TRADE_OFF_PARAM = TRADE_OFF_PARAM,
                                    ITERATION = ITERATION,
                                    NUM_THREADS = NUM_THREADS,
                                    CONVERGE = CONVERGE)

# %% [markdown]
# # 3. Preparation of mesh files

# %%
# output directory
outdir = 'meshGen/files'

# %%
# create meshGen object
mesh01 = femticPy.MeshGen(inversion.survey,
                         inversion.analysis_domain, 
                         inversion.center, 
                         inversion.mt_coords,
                         inversion.nRx_Z,
                         outdir)

# %%
mesh01.sea = True
mesh01.sea
# Out:
# True

# %%
# Step 1: 

# Define the mesh disretization, sphere centered on the mesh center 
    # core area: 650km sphere radius (isotropic) / max cell size : 50km (anisotropic in z)
    # padding: 2000km sphere radius (isotropic), max cell size: 500km (isotropic)

#the center in z of the mesh for the main ellipses should be at the mean elevation of the MT sites
import numpy as np
z_center = np.mean(mesh01.mt_coords['z'])

mesh01.center = [0.0, 0.0, -z_center]
mesh01.rotation = 0
mesh01.ellipsoids_control = [2,
                     [100.0, 5.0, 0.35, 0.5, 0.0], # here set an oblatness in the NS direction for the ellipse
                     [500.0, 50.0, 0.0, 0.0, 0.0]]

mesh01.coast_line = './input_data/coast_line.dat'

mesh01.ellipsoids_observing_sites =  [3, 
                                      1.0, 0.5,
                                      5.0, 1.0,
                                     50.0, 15.0]

# %%
# Step 6: Refine
# this step refines the tetras around the MT sites

mesh01.ellipsoids_obs_sites = [2,
                    [1.0, 0.5, 0.0] ,          
                    [3.0, 1.0, 0.0]]


mesh01.ellipsoids_mtr = [2,
                    [100.0, 5.0, 0.0, 0.1, 0.1],
                    [500.0, 50.0, 0.0, 0.0, 0.0]]

# %%
# Step 7: Write mesh to FEMTIC format
# the attr file will determine how tetras will be combined to do elememnts (model parameters)

mesh01.ellipsoids_resistivity_attr = [2,
                    [100.0,       5.0,  0.0,  0.0],
                    [500.0,  50.0,  0.0,  0.0]] 


mesh01.ellipsoids_resistivity_attr_sites = [2,                        
                    [2.0, 1.0],
                    [20.0, 10.0]]

# %%
# Define the starting model resistivities (in ohm.m)
mesh01.resistivity_starting_model = 20

# %%
mesh01.write_inputs()

# %%
# number of regions (air, land, sea) 
mesh01.region_attributes
# Out:
# 3

# %% [markdown]
# # 4. Run `create_mesh.sh`

# %% [markdown]
# the `create_mesh.sh` script call the `meshGen.sh` pipeline, that sequentially runs all the steps required to create the mesh. Depending on the size of the mesh this can take long (~ 10 min).
#
# "Step 4" in `meshGen.sh` needs to be modified to your problem:

# %% [markdown]
# ```
# #-----------------------"
# #-----   STEP 4    -----"
# #-----------------------"
#
# echo "STEP 4... "
# /scratch3/sei029/femtic/makeTetraMesh -stp 4
# sed -i "$(( $(wc -l < output.poly) ))s/.*/3/" output.poly
# echo "1   0.0 0.0 -40.0  10 1e9" >> output.poly
# echo "2  0.0 0.0  1.0  20 1e9" >> output.poly
# echo "3   0.0 0.0  40.0  30 1e9" >> output.poly
# echo "   done!"
# sleep 1
# ```

# %% [markdown]
# In this step, 3 lines are added to the `output.poly` file. They correspond to:
#
# `"region_attribute   x   y   z   region_number   1e9"`
#
# x, y, z (in km) should indicate at which location a sample of each region can be found. z is positive downwards.
#
# The region numbers have to match with the ones in `resistivity_attr.dat`
#
# ```
# 3
# 10 1.0e+9 -1 1
# 20 0.250  -1 1
# 30 100.0   9 0
# ```
#
# 10 is for air, 20 for sea and 30 for earth (with associated resistivities)

# %% [markdown]
# "Step 5" in `meshGen.sh` calls a python script that fixes a bug that has been appearing sometimes. This is a temporary fix while understanding why a new region number (31 or 32) sometimes appears during step 5.
#
# ```
# echo "fix output.1.ele if necessary... "
# module load python
# python fix_output1.py
# sleep 1
# echo "   done!"
# ```

# %% [markdown]
# # 5. Visualisation of the mesh using paraview (before running the inversion)

# %% [markdown]
# Setting up the ellipsoids is cumbersome and takes some trials to obtain a mesh that looks ok, in terms of cells discretization and mesh size.
#
# If the shell script has run properly, the final files to be used for the inversion should be:
# - resistivity_block_iter0.dat
# - mesh.dat

# %% [markdown]
# The output files that can be copied over and are useful for visualization are:
#
# - output.6.femtic.vtk
#    - to check the model parameter discretization (the cells), use the blockSerial attribute of the .vtk file
# - triangles_with_height.vtk
# - coastLine_fine.vtk
# - coastLine_rough.vtk
#
# The last 3 files are in km, and a transform filter has to be applied in paraview to be visualized with `output.6.femtic.vtk` (which is m)

# %% [markdown]
# # 6. Running the inversion using `run_inversion.sh`
